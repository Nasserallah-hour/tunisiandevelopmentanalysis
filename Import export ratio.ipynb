# %%
import pandas as pd
Currncy_conversion_dataframe=pd.read_csv("External trade conversion factors by countries.csv")
Currncy_conversion_dataframe
# Out:
#       series_type table_type     table_type_desc  country_code country_type  \
# 0       T38.A.CF.        T38  Conversion factors            12            C
# 1       T38.A.CF.        T38  Conversion factors            12            C
# 2       T38.A.CF.        T38  Conversion factors            16            C
# 3       T38.A.CF.        T38  Conversion factors            16            C
# 4       T38.A.CF.        T38  Conversion factors            24            C
# ...           ...        ...                 ...           ...          ...
# 27834   T38.A.CF.        T38  Conversion factors           882            C
# 27835   T38.A.CF.        T38  Conversion factors           887            C
# 27836   T38.A.CF.        T38  Conversion factors           887            C
# 27837   T38.A.CF.        T38  Conversion factors           894            C
# 27838   T38.A.CF.        T38  Conversion factors           894            C
#
# ...

# %%
Import_Or_export_dataframe = pd.read_csv("Imports and exports and indices for countries in national currency.csv")
Import_Or_export_dataframe.head()
# Out:
#   series_type table_type                          table_type_desc  \
# 0   T36.A.V.$        T36  Total trade - value, volume, unit value
# 1   T36.A.V.$        T36  Total trade - value, volume, unit value
# 2   T36.A.V.$        T36  Total trade - value, volume, unit value
# 3   T36.A.V.$        T36  Total trade - value, volume, unit value
# 4   T36.A.V.$        T36  Total trade - value, volume, unit value
#
#    country_code country_type country_english_name  year period_type  \
# 0            24            C               Angola  1945           A
# 1            24            C               Angola  1945           A
# 2            16            C       American Samoa  1946           A
# 3            16            C       American Samoa  1946           A
# 4            24            C               Angola  1946           A
#
#    period_number  period  ... partner_country_code  \
# 0              0  194552  ...                    0
# 1              0  194552  ...                    0
# ...

# %%
Total_trade_dataframe = pd.read_csv("Imports and exports for countries and regions in U.S. dollars.csv")
Total_trade_dataframe["trade_flow"]
# Out:
# 0        M
# 1        X
# 2        M
# 3        X
# 4        M
#         ..
# 32866    X
# 32867    M
# 32868    X
# 32869    M
# 32870    X
# Name: trade_flow, Length: 32871, dtype: object

# %%
pd.set_option("plotting.backend", "plotly")

# %%
import plotly.express as px

# %%
c=Currncy_conversion_dataframe[["country_english_name","year","value"]]
ix=Import_Or_export_dataframe[["country_english_name","year","value"]]

# %%
import plotly.express as px
df = Import_Or_export_dataframe # this is a pandas DataFrame
fig = px.scatter(df, x="year", y="value", color="country_english_name")
fig.show()
# Out:
# <div>                            <div id="db855c83-6f12-4863-aeac-b5ee2d799fd5" class="plotly-graph-div" style="height:525px; width:100%;"></div>            <script type="text/javascript">                require(["plotly"], function(Plotly) {                    window.PLOTLYENV=window.PLOTLYENV || {};                                    if (document.getElementById("db855c83-6f12-4863-aeac-b5ee2d799fd5")) {                    Plotly.newPlot(                        "db855c83-6f12-4863-aeac-b5ee2d799fd5",                        [{"hovertemplate":"country_english_name=Angola<br>year=%{x}<br>value=%{y}<extra></extra>","legendgroup":"Angola","marker":{"color":"#636efa","symbol":"circle"},"mode":"markers","name":"Angola","showlegend":true,"x":[1945,1945,1946,1946,1947,1947,1948,1948,1949,1949,1950,1950,1951,1951,1952,1952,1953,1953,1954,1954,1955,1955,1956,1956,1957,1957,1958,1958,1959,1959,1960,1960,1961,1961,1962,1962,1963,1963,1964,1964,1965,1965,1966,1966,1967,1967,1968,1968,1969,1969,19
# ...

# %%
arab= ["Algeria", "Bahrain", "Comoros", "Djibouti", "Egypt", "Iraq", "Jordan", "Kuwait", "Lebanon", "Libya", "Mauritania", "Morocco", "Oman", "Palestine", "Qatar", "Saudi Arabia", "Somalia", "Sudan", "Syria", "Tunisia", "United Arab Emirates", "Yemen"]

# %%
arabDF=Import_Or_export_dataframe[Import_Or_export_dataframe.country_english_name.isin(arab)]

# %%
fig = px.scatter(arabDF, x="year", y="value", color="country_english_name")
fig.show()
# Out:
# <div>                            <div id="9d49c59a-4dcf-4994-9463-93116621e2b0" class="plotly-graph-div" style="height:525px; width:100%;"></div>            <script type="text/javascript">                require(["plotly"], function(Plotly) {                    window.PLOTLYENV=window.PLOTLYENV || {};                                    if (document.getElementById("9d49c59a-4dcf-4994-9463-93116621e2b0")) {                    Plotly.newPlot(                        "9d49c59a-4dcf-4994-9463-93116621e2b0",                        [{"hovertemplate":"country_english_name=Iraq<br>year=%{x}<br>value=%{y}<extra></extra>","legendgroup":"Iraq","marker":{"color":"#636efa","symbol":"circle"},"mode":"markers","name":"Iraq","showlegend":true,"x":[1946,1947,1948,1949,1950,1951,1952,1953,1954,1955,1956,1957,1958,1959,1960,1961,1962,1963,1964,1965,1966,1967,1968,1969,1970,1971,1972,1973,1974,1975,1976,1977,1978,1979,1980,1981,2000,2000,2001,2001,2002,2002,2003,2003,2004,2004,2005,2005,2006,2006,2007,200
# ...

# %%
UMA= ["Morocco", "Tunisia","Egypt"]
umaDF=Import_Or_export_dataframe[Import_Or_export_dataframe.country_english_name.isin(UMA)]
fig = px.scatter(umaDF, x="year", y="value", color="country_english_name",symbol="trade_flow")
fig.update_traces(marker=dict(size=12,
                              line=dict(width=2,
                                        color='DarkSlateGrey')),
                  selector=dict(mode='markers'))
fig.show()
# Out:
# <div>                            <div id="fd64243e-cce0-4839-bded-1737a1489ed1" class="plotly-graph-div" style="height:525px; width:100%;"></div>            <script type="text/javascript">                require(["plotly"], function(Plotly) {                    window.PLOTLYENV=window.PLOTLYENV || {};                                    if (document.getElementById("fd64243e-cce0-4839-bded-1737a1489ed1")) {                    Plotly.newPlot(                        "fd64243e-cce0-4839-bded-1737a1489ed1",                        [{"hovertemplate":"country_english_name=Egypt<br>trade_flow=M<br>year=%{x}<br>value=%{y}<extra></extra>","legendgroup":"Egypt, M","marker":{"color":"#636efa","symbol":"circle","line":{"color":"DarkSlateGrey","width":2},"size":12},"mode":"markers","name":"Egypt, M","orientation":"v","showlegend":true,"x":[1946,1947,1948,1949,1950,1951,1952,1953,1954,1955,1956,1957,1958,1959,1960,1961,1962,1963,1964,1965,1966,1967,1968,1969,1970,1971,1972,1973,1974,1975,1976,1977,19
# ...
